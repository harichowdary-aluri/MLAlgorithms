# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
Bivariate Analysis
numerical VS Categorical
use case: Aggregate analysis of groups

# %%
children=[90,55,82,64,79]
color=['red','yellow','green','blue','pink']
plt.bar(color,children,color='pink')
# Out:
# <BarContainer object of 5 artists>

# %%
#barh to get the bars in horizontal direction
#if we have more categorial data we go for horizontal bars
plt.barh(color,children,color='pink')
# Out:
# <BarContainer object of 5 artists>

# %%
df=pd.read_csv('batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
#graph is not at all good
plt.bar(df['batsman'],df['2015'],width=0.6)
plt.bar(df['batsman'],df['2016'],width=0.4)
plt.bar(df['batsman'],df['2017'],width=0.2)
# Out:
# <BarContainer object of 5 artists>

# %%
# df.shape[0] = first column count vasthundhi
plt.bar(np.arange(df.shape[0])-0.2,df['2015'],width=0.2)
plt.bar(np.arange(df.shape[0]),df['2016'],width=0.2)
plt.bar(np.arange(df.shape[0])+0.2,df['2017'],width=0.2)
plt.xticks(np.arange(df.shape[0]),df['batsman'])
# Out:
# ([<matplotlib.axis.XTick at 0x172edbe50>,
# ...
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])

# %%
#x axis lo category data chala pedda ga vundhi anukoo appudu overlap avuthai perulu like below
children=[90,55,82,64,79]
color=['redFacewashFacewashFacewash','yellowFacewashFacewashFacewash','greenFacewashFacewashFacewash','blueFacewashFacewashFacewashFacewash','pinkFacewashFacewashFacewashFacewash']
plt.bar(color,children,color='pink')
# Out:
# <BarContainer object of 5 artists>

# %%
#x axis lo category data chala pedda ga vundhi anukoo appudu overlap avuthai perulu like below
children=[90,55,82,64,79]
color=['redFacewashFacewashFacewash','yellowFacewashFacewashFacewash','greenFacewashFacewashFacewash','blueFacewashFacewashFacewashFacewash','pinkFacewashFacewashFacewashFacewash']
plt.bar(color,children,color='pink')
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'redFacewashFacewashFacewash'),
#   Text(1, 0, 'yellowFacewashFacewashFacewash'),
#   Text(2, 0, 'greenFacewashFacewashFacewash'),
#   Text(3, 0, 'blueFacewashFacewashFacewashFacewash'),
#   Text(4, 0, 'pinkFacewashFacewashFacewashFacewash')])

# %%
plt.bar(df['batsman'],df['2015'],label='2015')
plt.bar(df['batsman'],df['2016'],bottom=df['2015'],label='2016')
plt.bar(df['batsman'],df['2017'],bottom=(df['2015']+df['2016']),label='2017')
plt.legend()
plt.show()
