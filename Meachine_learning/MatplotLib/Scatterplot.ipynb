# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
Bivariate analysis 
numerical vs numerical only
use case : finding correlation (btw tow quantities)
Scatter plot is the main thing and if we draw a lines in between them it will become 2D plot
# Out:
#   Cell In[14], line 4
#     Scatter plot is the main thing and if we draw a lines in between them it will become 2D plot
#                                                                                          ^
# SyntaxError: invalid decimal literal

# %%
df=pd.read_csv('batter.csv')
df=df.head(50)

# %%
plt.scatter(df['avg'],df['strike_rate'],color='red',marker='+')
plt.title('avg and strike rate analysis of top 50 batsman')
# Out:
# Text(0.5, 1.0, 'avg and strike rate analysis of top 50 batsman')

# %%
#size
tips=seaborn.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#size : the below graph show the 3D representation of information like totalbill, tip,
#customers group ga vacchara lekapothey oka okaru vacchara
plt.scatter(tips['total_bill'],tips['tip'],marker='D',s=tips['size']*20)

# %%
#Scatter plot using plot command
#size and color cannot be used 
#the use of plot is it is very faster 
plt.plot(tips['total_bill'],tips['tip'],'o')
