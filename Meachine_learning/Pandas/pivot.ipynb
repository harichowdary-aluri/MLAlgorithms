# %%
import pandas as pd
df=pd.read_csv("weather.csv")
df
# Out:
#        Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  \
# 0               0  2008-12-01   Albury     13.4     22.9       0.6
# 1               1  2008-12-02   Albury      7.4     25.1       0.0
# 2               2  2008-12-03   Albury     12.9     25.7       0.0
# 3               3  2008-12-04   Albury      9.2     28.0       0.0
# 4               4  2008-12-05   Albury     17.5     32.3       1.0
# ...           ...         ...      ...      ...      ...       ...
# 24995       24995  2013-03-09  Penrith     16.5     30.0       0.0
# 24996       24996  2013-03-10  Penrith     16.7     30.5       0.0
# 24997       24997  2013-03-11  Penrith     18.3     29.8       0.0
# 24998       24998  2013-03-12  Penrith     17.5     28.1       0.0
# 24999       24999  2013-03-13  Penrith     15.4     30.9       0.0
#
#        Evaporation  Sunshine WindGustDir  WindGustSpeed  ... Humidity3pm  \
# 0              NaN       NaN           W           44.0  ...        22.0
# ...

# %%
df=df.pivot(index='Date',columns='Location',values='Rainfall')
df

# %%
#PIVOT table is used to summarize and aggregate data inside data frame
df.pivot_table(index='Location',columns='Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 #PIVOT table is used to summarize and aggregate data inside data frame
# ----> 2 df.pivot_table(index='Location',columns='Date')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9190, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9173 @Substitution("")
#    9174 @Appender(_shared_docs["pivot_table"])
#    9175 def pivot_table(
#    (...)
#    9186     sort: bool = True,
#    9187 ) -> DataFrame:
#    9188     from pandas.core.reshape.pivot import pivot_table
# -> 9190     return pivot_table(
#    9191         self,
#    9192         values=values,
#    9193         index=index,
#    9194         columns=columns,
#    9195         aggfunc=aggfunc,
#    9196         fill_value=fill_value,
# ...
