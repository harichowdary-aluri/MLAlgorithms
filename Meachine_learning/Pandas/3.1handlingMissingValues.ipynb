# %%
import pandas as pd
df=pd.read_csv("climate_change_indicators.csv")
df.head(20)
# Out:
#     ObjectId                            Country ISO2 ISO3  \
# 0          1       Afghanistan, Islamic Rep. of   AF  AFG
# 1          2                            Albania   AL  ALB
# 2          3                            Algeria   DZ  DZA
# 3          4                     American Samoa   AS  ASM
# 4          5           Andorra, Principality of   AD  AND
# 5          6                             Angola   AO  AGO
# 6          7                           Anguilla   AI  AIA
# 7          8                Antigua and Barbuda   AG  ATG
# 8          9                          Argentina   AR  ARG
# 9         10                   Armenia, Rep. of   AM  ARM
# 10        11  Aruba, Kingdom of the Netherlands   AW  ABW
# 11        12                          Australia   AU  AUS
# 12        13                            Austria   AT  AUT
# 13        14                Azerbaijan, Rep. of   AZ  AZE
# 14        15                       Bahamas, The   BS  BHS
# ...

# %%
df=pd.read_csv("climate_change_indicators.csv",skiprows=2) #df=pd.read_csv("climate_change_indicators.csv",header=2)
df.tail(20)
# Out:
#        2                         Albania   AL  ALB  \
# 203  206        Turks and Caicos Islands   TC  TCA
# 204  207                          Tuvalu   TV  TUV
# 205  208                          Uganda   UG  UGA
# 206  209                         Ukraine   UA  UKR
# 207  210            United Arab Emirates   AE  ARE
# 208  211                  United Kingdom   GB  GBR
# 209  212                   United States   US  USA
# 210  213    United States Virgin Islands   VI  VIR
# 211  214                         Uruguay   UY  URY
# 212  215             Uzbekistan, Rep. of   UZ  UZB
# 213  216                         Vanuatu   VU  VUT
# 214  217  Venezuela, Rep. Bolivariana de   VE  VEN
# 215  218                         Vietnam   VN  VNM
# 216  219       Wallis and Futuna Islands   WF  WLF
# 217  220              West Bank and Gaza   PS  PSE
# 218  221                  Western Sahara   EH  ESH
# 219  222                           World  NaN  WLD
# ...

# %%
#if there is a situation where there is no header
import pandas as pd
df=pd.read_csv("climate_change_indicators.csv",header=None,names=["ukhdfds","dfdsf","dsjjf","dsjbkdjkds"])
df[0:72:9]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ukhdfds  \
# ...

# %%
df=pd.read_csv("climate_change_indicators.csv",nrows=3)
print(df.describe())
df[0:72:12]
# Out:
#        ObjectId     F1961    F1962     F1963     F1964  F1965     F1966  \
# count       3.0  3.000000  3.00000  3.000000  3.000000  3.000  3.000000
# mean        2.0  0.226000  0.09200  0.333000 -0.226667 -0.244  0.406000
# std         1.0  0.373876  0.24574  0.445138  0.509715  0.144  0.168134
# min         1.0 -0.113000 -0.16400  0.075000 -0.764000 -0.388  0.226000
# 25%         1.5  0.025500 -0.02500  0.076000 -0.465000 -0.316  0.329500
# 50%         2.0  0.164000  0.11400  0.077000 -0.166000 -0.244  0.433000
# 75%         2.5  0.395500  0.22000  0.462000  0.042000 -0.172  0.496000
# max         3.0  0.627000  0.32600  0.847000  0.250000 -0.100  0.559000
#
#           F1967     F1968     F1969  ...     F2013     F2014     F2015  \
# count  3.000000  3.000000  3.000000  ...  3.000000  3.000000  3.000000
# mean  -0.157000 -0.136333 -0.087000  ...  1.268667  1.114667  1.261000
# std    0.186877  0.259055  0.419919  ...  0.071305  0.621206  0.267103
# ...

# %%
#df=pd.read_csv("climate_change_indicators.csv",na_values=["not available"])

# %%
#konni columns lo -1 vuntai oka dantlo -1 anthe vundali inkokadantlo data ni NAN ki replace chayyali anukuntey we can write as below

'''df=pd.read_csv("climate_change_indicators.csv",na_values={
    'eps':["not available","n.a. "],
    'revenue' :["not availble ","n.a. ",-1],
    'people':["not available","n.a. "],
})'''
df.to_csv("new.csv",header=False)

# %%
'''
def conver_people_cell(cell):
    if cell=="n.a. ":
        return 'sam walton'
    return cell
df= pd.read_excel("climate_change_indicators.csv","Sheet1",converters={
    'people':conver_people_cell
})

'''
# Out:
# '\ndef conver_people_cell(cell):\n    if cell=="n.a. ":\n        return \'sam walton\'\n    return cell\ndf= pd.read_excel("climate_change_indicators.csv","Sheet1",converters={\n    \'people\':conver_people_cell\n})\n\n'
